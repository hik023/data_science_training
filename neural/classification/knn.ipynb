# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../films.csv", sep=";")
df.head()
# Out:
#                              Название фильма  Год выпуска                Жанр  \
# 0                               Интерстеллар         2014  Научная фантастика
# 1  Звездные войны: Эпизод IV - Новая надежда         1977  Научная фантастика
# 2                              Темный рыцарь         2008              Боевик
# 3           Властелин колец: Братство Кольца         2001             Фэнтези
# 4                               Зеленая миля         1999               Драма
#
#    Оценка пользователя                                        Комментарий  \
# 0                    5  Фантастический фильм с потрясающей игрой актер...
# 1                    4  Классический фильм, который все еще держит пла...
# 2                    5  Отличный боевик с умопомрачительным сюжетом и ...
# 3                    5  Эпическое приключение с великолепными персонаж...
# 4                    4     Глубокий фильм, который заставляет задуматься.
#
#            Метка
# 0  Положительный
# ...

# %%
df.groupby(df["Метка"]).agg({"Метка": ["count"]})
# Out:
#               Метка
#               count
# Метка
# Нейтральный       1
# Отрицательный     8
# Положительный    28

# %%
df.loc[df["Метка"] == "Отрицательный"]
# Out:
#                Название фильма  Год выпуска     Жанр  Оценка пользователя  \
# 29               Ужасный фильм         2022    Ужасы                    1
# 30                Фильм ужасен         2019    Ужасы                    2
# 31               Не понравился         2005    Драма                    2
# 32               Скучный фильм         2010    Драма                    2
# 33                Плохой фильм         2018  Комедия                    1
# 34               Не рекомендую         2017    Драма                    2
# 35         Самый ужасный фильм         2016    Ужасы                    1
# 36  Фильм полное разочарование         2021  Комедия                    1
#
#                                           Комментарий          Метка
# 29  Фильм ужасен, плохая игра актеров и нелепый сю...  Отрицательный
# 30  Пустой фильм с плохой режиссурой и неубедитель...  Отрицательный
# 31  Фильм вызвал разочарование, скучный и непонятн...  Отрицательный
# ...
