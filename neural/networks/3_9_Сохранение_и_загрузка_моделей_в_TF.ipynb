# %% [markdown]
# # Сохранение и возобновление обучения в Tensorflow
#
# До этого момента мы с вами работали с "игрушечными" данными и основной целью было понять основные механизмы работы фреймворка, обучения и построения моделей.
#
# Раньше мы не думали о том, как можно использовать обученную модель в будущем и сохранять параметры, которые мы получили во время обучения.
#
# Именно об этих возможностях, обязательных в практическом применении сетей, и пойдет речь в этом уроке.

# %% [markdown]
# ## Датасет
#
# В этом уроке мы будем работать с датасетом Pima Indian Diabetes, в котором приведены данные о состоянии здоровья людей. Помимо физиологических показаний, в данных есть информация о наличии у человека диабета. Это и будет считаться классом.

# %%
# загрузим данные
! wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
import pandas as pd

dataset = pd.read_csv("pima-indians-diabetes.data.csv", header=None)
dataset.columns = ["number_times_pregnant",
"plasma_glucose_concent","blood_pressure",
"skin_thickness", "insulin", "BMI", "diabetes_pedigree", "age", "has_diabetes"]
dataset.head()
# Out:
# --2024-05-02 16:51:06--  https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23278 (23K) [text/plain]
# Saving to: ‘pima-indians-diabetes.data.csv.1’
#
# pima-indians-diabet 100%[===================>]  22,73K  --.-KB/s    in 0,008s
#
# 2024-05-02 16:51:07 (2,69 MB/s) - ‘pima-indians-diabetes.data.csv.1’ saved [23278/23278]
#    number_times_pregnant  plasma_glucose_concent  blood_pressure  \
# 0                      6                     148              72
# 1                      1                      85              66
# 2                      8                     183              64
# 3                      1                      89              66
# 4                      0                     137              40
#
#    skin_thickness  insulin   BMI  diabetes_pedigree  age  has_diabetes
# 0              35        0  33.6              0.627   50             1
# 1              29        0  26.6              0.351   31             0
# 2               0        0  23.3              0.672   32             1
# 3              23       94  28.1              0.167   21             0
# 4              35      168  43.1              2.288   33             1

# %%
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(10)
X = dataset.drop(['has_diabetes'], axis=1).values
y = dataset['has_diabetes'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}, Labels ratio: {y_train.mean():.2f}")
# Out:
# Train shape: (614, 8), Test shape: (154, 8), Labels ratio: 0.34

# %% [markdown]
# ## Сохранение и загрузка моделей
#
# Т.к. параметры нашей модели трансформируются путем оптимизации из случайных -- в полезные для нашей задачи, нам бы хотелось сохранять этот прогресс. Было бы неразумно каждый раз обучать модель заново. Сохранение параметров модели во время обучения называют -- чекпоинтом (checkpoint).
#
# Подходы к сохранению моделей могут варьироваться в зависимости от количества данных и сложности модели. Все они сводятся к правилам по которым решается когда сохранять модель. Приведем самые популярные из таких правил:
# *   Сохранение в конце каждой эпохи
# *   Сохранение каждые k эпох
# *   Сохранение только последней эпохи
# *   Сохранение весов при улучшении метрики

# %%
import tensorflow as tf
import numpy as np
#tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 2024-05-02 16:51:08.034329: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 16:51:08.997283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.16.1

# %% [markdown]
# Для начала обучим модель и убедимся, что все работает:

# %%
def get_compiled_model():
    """
    Функция возвращает скомпилированную модель для бинарной классификации
    """
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(24, input_dim=8, activation='relu'))
    model.add(tf.keras.layers.Dense(24, activation='relu'))
    model.add(tf.keras.layers.Dense(24, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=1)
# Out:
# Epoch 1/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.
150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7684 - loss: 0.4618 - val_accuracy: 0.7338 - val_loss: 0.5715
# Epoch 132/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8082 - loss: 0.4197 - val_accuracy: 0.7273 - val_loss: 0.6016
# Epoch 133/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8074 - loss: 0.4122 - val_accuracy: 0.6948 - val_loss: 0.6259
# Epoch 134/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.4409 - val_accuracy: 0.6883 - val_loss: 0.6406
# Epoch 135/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7931 - loss: 0.4419 - val_accuracy: 0.7403 - val_loss: 0.5593
# Epoch 136/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8200 - loss: 0.4114 - val_accuracy: 0.6818 - val_loss: 0.6139
# Epoch 137/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7876 - loss: 0.4239 - val_accuracy: 0.7273 - val_loss: 0.5914
# Epoch 138/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8038 - loss: 0.4275 - val_accuracy: 0.6558 - val_loss: 0.6958
# Epoch 139/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7892 - loss: 0.4600 - val_accuracy: 0.7208 - val_loss: 0.5294
# Epoch 140/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7786 - loss: 0.4474 - val_accuracy: 0.7597 - val_loss: 0.5649
# Epoch 141/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8067 - loss: 0.4119 - val_accuracy: 0.7273 - val_loss: 0.5656
# Epoch 142/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.4304 - val_accuracy: 0.7338 - val_loss: 0.5584
# Epoch 143/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7785 - loss: 0.4482 - val_accuracy: 0.7208 - val_loss: 0.5567
# Epoch 144/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8225 - loss: 0.4315 - val_accuracy: 0.7143 - val_loss: 0.6008
# Epoch 145/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8220 - loss: 0.4026 - val_accuracy: 0.7078 - val_loss: 0.6222
# Epoch 146/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7896 - loss: 0.4206 - val_accuracy: 0.6753 - val_loss: 0.6636
# Epoch 147/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8351 - loss: 0.3808 - val_accuracy: 0.7143 - val_loss: 0.6314
# Epoch 148/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8242 - loss: 0.3762 - val_accuracy: 0.7208 - val_loss: 0.5984
# Epoch 149/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8359 - loss: 0.3634 - val_accuracy: 0.7078 - val_loss: 0.6081
# Epoch 150/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8261 - loss: 0.4009 - val_accuracy: 0.7403 - val_loss: 0.6179

# %% [markdown]
# ### Сохранение модели
#
# За запись чекпоинтов в keras отвечает **tf.keras.callbacks.ModelCheckpoint**. Как видно из пути к модулю -- он относится к коллбекам (callbacks). Можно смотреть на них как на функции, которые вызывает метод model.fit внутри себя.
#
# То есть каждый раз, когда отработает одна из эпох цикла, будет запускаться функция, которую мы укажем. Бывают коллбеки, которые вызываются на каждой итерации (например [прогресс бар](https://keras.io/callbacks/#progbarlogger), который мы видим при обучении -- это тоже коллбэк). Чуть ниже мы разберем конкретный пример.
#
# Вернемся к **tf.keras.callbacks.ModelCheckpoint**.
#
# ```
# tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', ...)
# ```
#
# Он имеет один обязательный параметр -- имя чекпоинта. Оно может быть отформатировано с использованием служебных переменных (пример ниже). Из необязательных, но полезных параметров:
#
# *   monitor (str): название метрики за которой нужно "следить"
# *   verbose -- печатать ли дополнительную информацию
# *   save_best_only (bool): сохранять чекпоинт только после улучшения метрики, указанной в monitor
# *   save_weights_only (bool): помимо весов модели можно еще сохранять ее архитектуру и состояние оптимизатора. В примерах мы так и будем делать, если не сказано обратное. По умолчанию -- false.
# *   mode (str): если метрику нужно максимизировать -- max, иначе -- min.
#
#
# **Таким образом, если выбрано save_best_only, то чекпоинты будут сохранятся только после тех эпох, когда произошло улучшение метрики, которую мы указали в monitor. Т.к. понятие "лучше" -- разное для разных метрик, необходимо также указать режим -- max/min (больше -- лучше/меньше -- лучше). Пример таких метрик -- лосс (min) и точность (max)**.

# %%
from pathlib import Path
path = Path("model_1")
path.mkdir(exist_ok=True) # создаем папку на диске
cpt_filename = "{epoch:02d}_checkpoint_{val_accuracy:.2f}.keras"
cpt_path = str(path / cpt_filename)

checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
tf.keras.callbacks.ModelCheckpoint?
# Out:
# Init signature:
# tf.keras.callbacks.ModelCheckpoint(
#     filepath,
#     monitor='val_loss',
#     verbose=0,
#     save_best_only=False,
#     save_weights_only=False,
#     mode='auto',
#     save_freq='epoch',
#     initial_value_threshold=None,
# )
# Docstring:
# Callback to save the Keras model or model weights at some frequency.
#
# `ModelCheckpoint` callback is used in conjunction with training using
# `model.fit()` to save a model or weights (in a checkpoint file) at some
# interval, so the model or weights can be loaded later to continue the
# training from the state saved.
#
# A few options this callback provides include:
#
# - Whether to only keep the model that has achieved the "best performance" so
#   far, or whether to save the model at the end of every epoch regardless of
#   performance.
# - Definition of "best"; which quantity to monitor and whether it should be
#   maximized or minimized.
# - The frequency it should save at. Currently, the callback supports saving
#   at the end of every epoch, or after a fixed number of training batches.
# - Whether only weights are saved, or the whole model is saved.
#
# Example:
#
# ```python
# model.compile(loss=..., optimizer=...,
#               metrics=['accuracy'])
#
# EPOCHS = 10
# checkpoint_filepath = '/tmp/ckpt/checkpoint.model.keras'
# model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_filepath,
#     monitor='val_accuracy',
#     mode='max',
#     save_best_only=True)
#
# # Model is saved at the end of every epoch, if it's the best seen so far.
# model.fit(epochs=EPOCHS, callbacks=[model_checkpoint_callback])
#
# # The model (that are considered the best) can be loaded as -
# keras.models.load_model(checkpoint_filepath)
#
# # Alternatively, one could checkpoint just the model weights as -
# checkpoint_filepath = '/tmp/ckpt/checkpoint.weights.h5'
# model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_filepath,
#     save_weights_only=True,
#     monitor='val_accuracy',
#     mode='max',
#     save_best_only=True)
#
# # Model weights are saved at the end of every epoch, if it's the best seen
# # so far.
# model.fit(epochs=EPOCHS, callbacks=[model_checkpoint_callback])
#
# # The model weights (that are considered the best) can be loaded as -
# model.load_weights(checkpoint_filepath)
# ```
#
# Args:
#     filepath: string or `PathLike`, path to save the model file.
#         `filepath` can contain named formatting options,
#         which will be filled the value of `epoch` and keys in `logs`
#         (passed in `on_epoch_end`).
#         The `filepath` name needs to end with `".weights.h5"` when
#         `save_weights_only=True` or should end with `".keras"` when
#         checkpoint saving the whole model (default).
#         For example:
#         if `filepath` is `"{epoch:02d}-{val_loss:.2f}.keras"`, then the
#         model checkpoints will be saved with the epoch number and the
#         validation loss in the filename. The directory of the filepath
#         should not be reused by any other callbacks to avoid conflicts.
#     monitor: The metric name to monitor. Typically the metrics are set by
#         the `Model.compile` method. Note:
#         * Prefix the name with `"val_"` to monitor validation metrics.
#         * Use `"loss"` or `"val_loss"` to monitor the model's total loss.
#         * If you specify metrics as strings, like `"accuracy"`, pass the
#             same string (with or without the `"val_"` prefix).
#         * If you pass `metrics.Metric` objects, `monitor` should be set to
#             `metric.name`
#         * If you're not sure about the metric names you can check the
#             contents of the `history.history` dictionary returned by
#             `history = model.fit()`
#         * Multi-output models set additional prefixes on the metric names.
#     verbose: Verbosity mode, 0 or 1. Mode 0 is silent, and mode 1
#         displays messages when the callback takes an action.
#     save_best_only: if `save_best_only=True`, it only saves when the model
#         is considered the "best" and the latest best model according to the
#         quantity monitored will not be overwritten. If `filepath` doesn't
#         contain formatting options like `{epoch}` then `filepath` will be
#         overwritten by each new better model.
#     mode: one of {`"auto"`, `"min"`, `"max"`}. If `save_best_only=True`, the
#         decision to overwrite the current save file is made based on either
#         the maximization or the minimization of the monitored quantity.
#         For `val_acc`, this should be `"max"`, for `val_loss` this should be
#         `"min"`, etc. In `"auto"` mode, the mode is set to `"max"` if the
#         quantities monitored are `"acc"` or start with `"fmeasure"` and are
#         set to `"min"` for the rest of the quantities.
#     save_weights_only: if `True`, then only the model's weights will be
#         saved (`model.save_weights(filepath)`), else the full model is
#         saved (`model.save(filepath)`).
#     save_freq: `"epoch"` or integer. When using `"epoch"`, the callback
#         saves the model after each epoch. When using integer, the callback
#         saves the model at end of this many batches. If the `Model` is
#         compiled with `steps_per_execution=N`, then the saving criteria will
#         be checked every Nth batch. Note that if the saving isn't aligned to
#         epochs, the monitored metric may potentially be less reliable (it
#         could reflect as little as 1 batch, since the metrics get reset
#         every epoch). Defaults to `"epoch"`.
#     initial_value_threshold: Floating point initial "best" value of the
#         metric to be monitored. Only applies if `save_best_value=True`. Only
#         overwrites the model weights already saved if the performance of
#         current model is better than this value.
# File:           /mnt/500_gb/data_science/.venv/lib/python3.12/site-packages/keras/src/callbacks/model_checkpoint.py
# Type:           type
# Subclasses:

# %%
"a={a_val}, b={b_val}".format(a_val=2, b_val=34)
# Out:
# 'a=2, b=34'

# %%
cpt_path
# Out:
# 'model_1/{epoch:02d}_checkpoint_{val_accuracy:.2f}.keras'

# %%
# внутри цикла имя чекпоинта будет сгенерировано примерно таким образом:
for epoch in range(4):
    print(cpt_path.format(epoch=epoch, val_accuracy=np.random.rand()))
# Out:
# model_1/00_checkpoint_0.97.keras
# model_1/01_checkpoint_0.99.keras
# model_1/02_checkpoint_0.78.keras
# model_1/03_checkpoint_0.94.keras

# %% [markdown]
# Мы используем hdf5 -- основной формат для keras. Для Tensorflow -- это ckpt. Сохранять в этом расширении можно аналогичным образом. Подробнее можно прочитать [здесь](https://www.tensorflow.org/tutorials/keras/save_and_restore_models).

# %%
model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=0,
          callbacks=[checkpoint])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.62338, saving model to model_1/01_checkpoint_0.62.keras
#
# Epoch 2: val_accuracy improved from 0.62338 to 0.66234, saving model to model_1/02_checkpoint_0.66.keras
#
# Epoch 3: val_accuracy did not improve from 0.66234
#
# Epoch 4: val_accuracy did not improve from 0.66234
#
# Epoch 5: val_accuracy did not improve from 0.66234
#
# Epoch 6: val_accuracy improved from 0.66234 to 0.67532, saving model to model_1/06_checkpoint_0.68.keras
#
# Epoch 7: val_accuracy did not improve from 0.67532
#
# Epoch 8: val_accuracy improved from 0.67532 to 0.68182, saving model to model_1/08_checkpoint_0.68.keras
#
# Epoch 9: val_accuracy did not improve from 0.68182
#
# Epoch 10: val_accuracy did not improve from 0.68182
#
# Epoch 11: val_accuracy did not improve from 0.68182
#
# Epoch 12: val_accuracy did not improve from 0.68182
#
# Epoch 13: val_accuracy did not improve from 0.68182
#
# Epoch 14: val_accuracy did not improve from 0.68182
#
# Epoch 15: val_accuracy did not improve from 0.68182
#
# Epoch 16: val_accuracy did not improve from 0.68182
#
# Epoch 17: val_accuracy did not improve from 0.68182
#
# Epoch 18: val_accuracy did not improve from 0.68182
#
# Epoch 19: val_accuracy did not improve from 0.68182
#
# Epoch 20: val_accuracy did not improve from 0.68182
#
# Epoch 21: val_accuracy did not improve from 0.68182
#
# Epoch 22: val_accuracy did not improve from 0.68182
#
# Epoch 23: val_accuracy improved from 0.68182 to 0.70779, saving model to model_1/23_checkpoint_0.71.keras
#
# Epoch 24: val_accuracy did not improve from 0.70779
#
# Epoch 25: val_accuracy did not improve from 0.70779
#
# Epoch 26: val_accuracy did not improve from 0.70779
#
# Epoch 27: val_accuracy did not improve from 0.70779
#
# Epoch 28: val_accuracy did not improve from 0.70779
#
# Epoch 29: val_accuracy did not improve from 0.70779
#
# Epoch 30: val_accuracy improved from 0.70779 to 0.72078, saving model to model_1/30_checkpoint_0.72.keras
#
# Epoch 31: val_accuracy did not improve from 0.72078
#
# Epoch 32: val_accuracy did not improve from 0.72078
#
# Epoch 33: val_accuracy did not improve from 0.72078
#
# Epoch 34: val_accuracy did not improve from 0.72078
#
# Epoch 35: val_accuracy did not improve from 0.72078
#
# Epoch 36: val_accuracy did not improve from 0.72078
#
# Epoch 37: val_accuracy did not improve from 0.72078
#
# Epoch 38: val_accuracy did not improve from 0.72078
#
# Epoch 39: val_accuracy did not improve from 0.72078
#
# Epoch 40: val_accuracy did not improve from 0.72078
#
# Epoch 41: val_accuracy did not improve from 0.72078
#
# Epoch 42: val_accuracy did not improve from 0.72078
#
# Epoch 43: val_accuracy did not improve from 0.72078
#
# Epoch 44: val_accuracy did not improve from 0.72078
#
# Epoch 45: val_accuracy did not improve from 0.72078
#
# Epoch 46: val_accuracy did not improve from 0.72078
#
# Epoch 47: val_accuracy did not improve from 0.72078
#
# Epoch 48: val_accuracy did not improve from 0.72078
#
# Epoch 49: val_accuracy did not improve from 0.72078
#
# Epoch 50: val_accuracy did not improve from 0.72078
#
# Epoch 51: val_accuracy did not improve from 0.72078
#
# Epoch 52: val_accuracy did not improve from 0.72078
#
# Epoch 53: val_accuracy did not improve from 0.72078
#
# Epoch 54: val_accuracy did not improve from 0.72078
#
# Epoch 55: val_accuracy did not improve from 0.72078
#
# Epoch 56: val_accuracy did not improve from 0.72078
#
# Epoch 57: val_accuracy did not improve from 0.72078
#
# Epoch 58: val_accuracy did not improve from 0.72078
#
# Epoch 59: val_accuracy did not improve from 0.72078
#
# Epoch 60: val_accuracy did not improve from 0.72078
#
# Epoch 61: val_accuracy did not improve from 0.72078
#
# Epoch 62: val_accuracy improved from 0.72078 to 0.72727, saving model to model_1/62_checkpoint_0.73.keras
#
# Epoch 63: val_accuracy did not improve from 0.72727
#
# Epoch 64: val_accuracy did not improve from 0.72727
#
# Epoch 65: val_accuracy did not improve from 0.72727
#
# Epoch 66: val_accuracy did not improve from 0.72727
#
# Epoch 67: val_accuracy did not improve from 0.72727
#
# Epoch 68: val_accuracy did not improve from 0.72727
#
# Epoch 69: val_accuracy did not improve from 0.72727
#
# Epoch 70: val_accuracy improved from 0.72727 to 0.73377, saving model to model_1/70_checkpoint_0.73.keras
#
# Epoch 71: val_accuracy did not improve from 0.73377
#
# Epoch 72: val_accuracy did not improve from 0.73377
#
# Epoch 73: val_accuracy did not improve from 0.73377
#
# Epoch 74: val_accuracy did not improve from 0.73377
#
# Epoch 75: val_accuracy did not improve from 0.73377
#
# Epoch 76: val_accuracy did not improve from 0.73377
#
# Epoch 77: val_accuracy did not improve from 0.73377
#
# Epoch 78: val_accuracy did not improve from 0.73377
#
# Epoch 79: val_accuracy did not improve from 0.73377
#
# Epoch 80: val_accuracy did not improve from 0.73377
#
# Epoch 81: val_accuracy did not improve from 0.73377
#
# Epoch 82: val_accuracy did not improve from 0.73377
#
# Epoch 83: val_accuracy did not improve from 0.73377
#
# Epoch 84: val_accuracy did not improve from 0.73377
#
# Epoch 85: val_accuracy did not improve from 0.73377
#
# Epoch 86: val_accuracy did not improve from 0.73377
#
# Epoch 87: val_accuracy did not improve from 0.73377
#
# Epoch 88: val_accuracy did not improve from 0.73377
#
# Epoch 89: val_accuracy did not improve from 0.73377
#
# Epoch 90: val_accuracy did not improve from 0.73377
#
# Epoch 91: val_accuracy did not improve from 0.73377
#
# Epoch 92: val_accuracy did not improve from 0.73377
#
# Epoch 93: val_accuracy did not improve from 0.73377
#
# Epoch 94: val_accuracy did not improve from 0.73377
#
# Epoch 95: val_accuracy did not improve from 0.73377
#
# Epoch 96: val_accuracy did not improve from 0.73377
#
# Epoch 97: val_accuracy did not improve from 0.73377
#
# Epoch 98: val_accuracy did not improve from 0.73377
#
# Epoch 99: val_accuracy did not improve from 0.73377
#
# Epoch 100: val_accuracy did not improve from 0.73377
#
# Epoch 101: val_accuracy improved from 0.73377 to 0.74675, saving model to model_1/101_checkpoint_0.75.keras
#
# Epoch 102: val_accuracy did not improve from 0.74675
#
# Epoch 103: val_accuracy did not improve from 0.74675
#
# Epoch 104: val_accuracy did not improve from 0.74675
#
# Epoch 105: val_accuracy did not improve from 0.74675
#
# Epoch 106: val_accuracy did not improve from 0.74675
#
# Epoch 107: val_accuracy improved from 0.74675 to 0.75325, saving model to model_1/107_checkpoint_0.75.keras
#
# Epoch 108: val_accuracy did not improve from 0.75325
#
# Epoch 109: val_accuracy did not improve from 0.75325
#
# Epoch 110: val_accuracy did not improve from 0.75325
#
# Epoch 111: val_accuracy did not improve from 0.75325
#
# Epoch 112: val_accuracy did not improve from 0.75325
#
# Epoch 113: val_accuracy did not improve from 0.75325
#
# Epoch 114: val_accuracy did not improve from 0.75325
#
# Epoch 115: val_accuracy did not improve from 0.75325
#
# Epoch 116: val_accuracy did not improve from 0.75325
#
# Epoch 117: val_accuracy did not improve from 0.75325
#
# Epoch 118: val_accuracy did not improve from 0.75325
#
# Epoch 119: val_accuracy did not improve from 0.75325
#
# Epoch 120: val_accuracy did not improve from 0.75325
#
# Epoch 121: val_accuracy did not improve from 0.75325
#
# Epoch 122: val_accuracy did not improve from 0.75325
#
# Epoch 123: val_accuracy did not improve from 0.75325
#
# Epoch 124: val_accuracy improved from 0.75325 to 0.75974, saving model to model_1/124_checkpoint_0.76.keras
#
# Epoch 125: val_accuracy did not improve from 0.75974
#
# Epoch 126: val_accuracy did not improve from 0.75974
#
# Epoch 127: val_accuracy did not improve from 0.75974
#
# Epoch 128: val_accuracy did not improve from 0.75974
#
# Epoch 129: val_accuracy did not improve from 0.75974
#
# Epoch 130: val_accuracy did not improve from 0.75974
#
# Epoch 131: val_accuracy did not improve from 0.75974
#
# Epoch 132: val_accuracy did not improve from 0.75974
#
# Epoch 133: val_accuracy did not improve from 0.75974
#
# Epoch 134: val_accuracy did not improve from 0.75974
#
# Epoch 135: val_accuracy did not improve from 0.75974
#
# Epoch 136: val_accuracy did not improve from 0.75974
#
# Epoch 137: val_accuracy did not improve from 0.75974
#
# Epoch 138: val_accuracy did not improve from 0.75974
#
# Epoch 139: val_accuracy did not improve from 0.75974
#
# Epoch 140: val_accuracy improved from 0.75974 to 0.78571, saving model to model_1/140_checkpoint_0.79.keras
#
# Epoch 141: val_accuracy did not improve from 0.78571
#
# Epoch 142: val_accuracy did not improve from 0.78571
#
# Epoch 143: val_accuracy did not improve from 0.78571
#
# Epoch 144: val_accuracy did not improve from 0.78571
#
# Epoch 145: val_accuracy did not improve from 0.78571
#
# Epoch 146: val_accuracy did not improve from 0.78571
#
# Epoch 147: val_accuracy did not improve from 0.78571
#
# Epoch 148: val_accuracy did not improve from 0.78571
#
# Epoch 149: val_accuracy did not improve from 0.78571
#
# Epoch 150: val_accuracy did not improve from 0.78571

# %% [markdown]
# Убедимся ниже, что файлы сохранены:

# %%
# !ls "model_1/"
# Out:
# 01_checkpoint_0.62.keras  101_checkpoint_0.75.keras  23_checkpoint_0.71.keras
# 02_checkpoint_0.66.keras  107_checkpoint_0.75.keras  30_checkpoint_0.72.keras
# 06_checkpoint_0.68.keras  124_checkpoint_0.76.keras  62_checkpoint_0.73.keras
# 08_checkpoint_0.68.keras  140_checkpoint_0.79.keras  70_checkpoint_0.73.keras

# %% [markdown]
# ### Загрузка модели
#
# Загрузить модель можно двумя способами. Определить модель и загрузить в нее веса, с использованием *model.load_weights()*. Или tf.keras.models.load_model для автоматического создания модели и загрузки весов (мы можем так сделать т.к. при создании чекпоинтов выставили save_weights_only=False, т.е. сохранили и описание модели).

# %%
model = get_compiled_model() # определим случайно инициализированную модель
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of random model {acc*100 :.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3560 - loss: 23.4429
# Accuracy of random model 38.31%

# %%
model.load_weights("model_1/70_checkpoint_0.73.keras") # загружаем веса. обратите внимание, модель уже создана!
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.7229 - loss: 0.5672
# Accuracy of restored model 73.38%

# %%
# т.к. мы сохраняли и веса и модель, то мы можем загрузить модель не определяя ее
model = tf.keras.models.load_model("model_1/70_checkpoint_0.73.keras")
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7229 - loss: 0.5672
# Accuracy of restored model 73.38%

# %% [markdown]
# ### Сохранение модели в один чекпоинт
# Если не форматировать название файла, то все чекпоинты будут записаны в него:

# %%
path = Path("model_2")
path.mkdir(exist_ok=True)
cpt_filename = "checkpoint_best.keras"
cpt_path =str(path / cpt_filename)

checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=0,
          callbacks=[checkpoint])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.61688, saving model to model_2/checkpoint_best.keras
#
# Epoch 2: val_accuracy did not improve from 0.61688
#
# Epoch 3: val_accuracy improved from 0.61688 to 0.62338, saving model to model_2/checkpoint_best.keras
#
# Epoch 4: val_accuracy improved from 0.62338 to 0.64286, saving model to model_2/checkpoint_best.keras
#
# Epoch 5: val_accuracy did not improve from 0.64286
#
# Epoch 6: val_accuracy improved from 0.64286 to 0.64935, saving model to model_2/checkpoint_best.keras
#
# Epoch 7: val_accuracy did not improve from 0.64935
#
# Epoch 8: val_accuracy did not improve from 0.64935
#
# Epoch 9: val_accuracy improved from 0.64935 to 0.67532, saving model to model_2/checkpoint_best.keras
#
# Epoch 10: val_accuracy did not improve from 0.67532
#
# Epoch 11: val_accuracy did not improve from 0.67532
#
# Epoch 12: val_accuracy did not improve from 0.67532
#
# Epoch 13: val_accuracy did not improve from 0.67532
#
# Epoch 14: val_accuracy did not improve from 0.67532
#
# Epoch 15: val_accuracy did not improve from 0.67532
#
# Epoch 16: val_accuracy did not improve from 0.67532
#
# Epoch 17: val_accuracy did not improve from 0.67532
#
# Epoch 18: val_accuracy did not improve from 0.67532
#
# Epoch 19: val_accuracy did not improve from 0.67532
#
# Epoch 20: val_accuracy did not improve from 0.67532
#
# Epoch 21: val_accuracy did not improve from 0.67532
#
# Epoch 22: val_accuracy did not improve from 0.67532
#
# Epoch 23: val_accuracy did not improve from 0.67532
#
# Epoch 24: val_accuracy did not improve from 0.67532
#
# Epoch 25: val_accuracy did not improve from 0.67532
#
# Epoch 26: val_accuracy did not improve from 0.67532
#
# Epoch 27: val_accuracy improved from 0.67532 to 0.70130, saving model to model_2/checkpoint_best.keras
#
# Epoch 28: val_accuracy did not improve from 0.70130
#
# Epoch 29: val_accuracy did not improve from 0.70130
#
# Epoch 30: val_accuracy did not improve from 0.70130
#
# Epoch 31: val_accuracy did not improve from 0.70130
#
# Epoch 32: val_accuracy did not improve from 0.70130
#
# Epoch 33: val_accuracy did not improve from 0.70130
#
# Epoch 34: val_accuracy did not improve from 0.70130
#
# Epoch 35: val_accuracy did not improve from 0.70130
#
# Epoch 36: val_accuracy did not improve from 0.70130
#
# Epoch 37: val_accuracy did not improve from 0.70130
#
# Epoch 38: val_accuracy did not improve from 0.70130
#
# Epoch 39: val_accuracy did not improve from 0.70130
#
# Epoch 40: val_accuracy did not improve from 0.70130
#
# Epoch 41: val_accuracy did not improve from 0.70130
#
# Epoch 42: val_accuracy did not improve from 0.70130
#
# Epoch 43: val_accuracy did not improve from 0.70130
#
# Epoch 44: val_accuracy did not improve from 0.70130
#
# Epoch 45: val_accuracy did not improve from 0.70130
#
# Epoch 46: val_accuracy did not improve from 0.70130
#
# Epoch 47: val_accuracy did not improve from 0.70130
#
# Epoch 48: val_accuracy did not improve from 0.70130
#
# Epoch 49: val_accuracy did not improve from 0.70130
#
# Epoch 50: val_accuracy did not improve from 0.70130
#
# Epoch 51: val_accuracy did not improve from 0.70130
#
# Epoch 52: val_accuracy did not improve from 0.70130
#
# Epoch 53: val_accuracy did not improve from 0.70130
#
# Epoch 54: val_accuracy did not improve from 0.70130
#
# Epoch 55: val_accuracy did not improve from 0.70130
#
# Epoch 56: val_accuracy did not improve from 0.70130
#
# Epoch 57: val_accuracy did not improve from 0.70130
#
# Epoch 58: val_accuracy did not improve from 0.70130
#
# Epoch 59: val_accuracy did not improve from 0.70130
#
# Epoch 60: val_accuracy did not improve from 0.70130
#
# Epoch 61: val_accuracy did not improve from 0.70130
#
# Epoch 62: val_accuracy did not improve from 0.70130
#
# Epoch 63: val_accuracy improved from 0.70130 to 0.74026, saving model to model_2/checkpoint_best.keras
#
# Epoch 64: val_accuracy did not improve from 0.74026
#
# Epoch 65: val_accuracy did not improve from 0.74026
#
# Epoch 66: val_accuracy did not improve from 0.74026
#
# Epoch 67: val_accuracy did not improve from 0.74026
#
# Epoch 68: val_accuracy did not improve from 0.74026
#
# Epoch 69: val_accuracy did not improve from 0.74026
#
# Epoch 70: val_accuracy did not improve from 0.74026
#
# Epoch 71: val_accuracy did not improve from 0.74026
#
# Epoch 72: val_accuracy did not improve from 0.74026
#
# Epoch 73: val_accuracy did not improve from 0.74026
#
# Epoch 74: val_accuracy did not improve from 0.74026
#
# Epoch 75: val_accuracy did not improve from 0.74026
#
# Epoch 76: val_accuracy did not improve from 0.74026
#
# Epoch 77: val_accuracy did not improve from 0.74026
#
# Epoch 78: val_accuracy did not improve from 0.74026
#
# Epoch 79: val_accuracy did not improve from 0.74026
#
# Epoch 80: val_accuracy did not improve from 0.74026
#
# Epoch 81: val_accuracy did not improve from 0.74026
#
# Epoch 82: val_accuracy did not improve from 0.74026
#
# Epoch 83: val_accuracy did not improve from 0.74026
#
# Epoch 84: val_accuracy did not improve from 0.74026
#
# Epoch 85: val_accuracy did not improve from 0.74026
#
# Epoch 86: val_accuracy did not improve from 0.74026
#
# Epoch 87: val_accuracy did not improve from 0.74026
#
# Epoch 88: val_accuracy did not improve from 0.74026
#
# Epoch 89: val_accuracy did not improve from 0.74026
#
# Epoch 90: val_accuracy did not improve from 0.74026
#
# Epoch 91: val_accuracy did not improve from 0.74026
#
# Epoch 92: val_accuracy did not improve from 0.74026
#
# Epoch 93: val_accuracy did not improve from 0.74026
#
# Epoch 94: val_accuracy did not improve from 0.74026
#
# Epoch 95: val_accuracy did not improve from 0.74026
#
# Epoch 96: val_accuracy did not improve from 0.74026
#
# Epoch 97: val_accuracy did not improve from 0.74026
#
# Epoch 98: val_accuracy did not improve from 0.74026
#
# Epoch 99: val_accuracy did not improve from 0.74026
#
# Epoch 100: val_accuracy did not improve from 0.74026
#
# Epoch 101: val_accuracy did not improve from 0.74026
#
# Epoch 102: val_accuracy did not improve from 0.74026
#
# Epoch 103: val_accuracy did not improve from 0.74026
#
# Epoch 104: val_accuracy did not improve from 0.74026
#
# Epoch 105: val_accuracy did not improve from 0.74026
#
# Epoch 106: val_accuracy did not improve from 0.74026
#
# Epoch 107: val_accuracy did not improve from 0.74026
#
# Epoch 108: val_accuracy did not improve from 0.74026
#
# Epoch 109: val_accuracy did not improve from 0.74026
#
# Epoch 110: val_accuracy did not improve from 0.74026
#
# Epoch 111: val_accuracy did not improve from 0.74026
#
# Epoch 112: val_accuracy did not improve from 0.74026
#
# Epoch 113: val_accuracy did not improve from 0.74026
#
# Epoch 114: val_accuracy did not improve from 0.74026
#
# Epoch 115: val_accuracy did not improve from 0.74026
#
# Epoch 116: val_accuracy did not improve from 0.74026
#
# Epoch 117: val_accuracy did not improve from 0.74026
#
# Epoch 118: val_accuracy did not improve from 0.74026
#
# Epoch 119: val_accuracy did not improve from 0.74026
#
# Epoch 120: val_accuracy did not improve from 0.74026
#
# Epoch 121: val_accuracy improved from 0.74026 to 0.75974, saving model to model_2/checkpoint_best.keras
#
# Epoch 122: val_accuracy did not improve from 0.75974
#
# Epoch 123: val_accuracy did not improve from 0.75974
#
# Epoch 124: val_accuracy did not improve from 0.75974
#
# Epoch 125: val_accuracy did not improve from 0.75974
#
# Epoch 126: val_accuracy did not improve from 0.75974
#
# Epoch 127: val_accuracy did not improve from 0.75974
#
# Epoch 128: val_accuracy did not improve from 0.75974
#
# Epoch 129: val_accuracy did not improve from 0.75974
#
# Epoch 130: val_accuracy did not improve from 0.75974
#
# Epoch 131: val_accuracy did not improve from 0.75974
#
# Epoch 132: val_accuracy did not improve from 0.75974
#
# Epoch 133: val_accuracy did not improve from 0.75974
#
# Epoch 134: val_accuracy did not improve from 0.75974
#
# Epoch 135: val_accuracy did not improve from 0.75974
#
# Epoch 136: val_accuracy did not improve from 0.75974
#
# Epoch 137: val_accuracy did not improve from 0.75974
#
# Epoch 138: val_accuracy did not improve from 0.75974
#
# Epoch 139: val_accuracy did not improve from 0.75974
#
# Epoch 140: val_accuracy did not improve from 0.75974
#
# Epoch 141: val_accuracy did not improve from 0.75974
#
# Epoch 142: val_accuracy did not improve from 0.75974
#
# Epoch 143: val_accuracy did not improve from 0.75974
#
# Epoch 144: val_accuracy did not improve from 0.75974
#
# Epoch 145: val_accuracy did not improve from 0.75974
#
# Epoch 146: val_accuracy did not improve from 0.75974
#
# Epoch 147: val_accuracy did not improve from 0.75974
#
# Epoch 148: val_accuracy did not improve from 0.75974
#
# Epoch 149: val_accuracy did not improve from 0.75974
#
# Epoch 150: val_accuracy did not improve from 0.75974

# %%
! ls model_2
# Out:
# checkpoint_best.keras

# %%
model = tf.keras.models.load_model("model_2/checkpoint_best.keras")
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7689 - loss: 0.6175
# Accuracy of restored model 75.97%

# %% [markdown]
# Сохранять один файл или несколько -- решать вам, это зависит от задач и принятых практик ведения экспериментов, например, в каких-то случаях может пригодится сравнить предсказания нескольких последних моделей.

# %% [markdown]
# ### Продолжение процесса обучения

# %%
# мы можем продолжить процесс обучения, обратите внимание на initial_epoch
model = tf.keras.models.load_model("model_2/checkpoint_best.keras")
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=300, batch_size=64, verbose=0,
          callbacks=[checkpoint], initial_epoch=150)
# Out:
# Epoch 151: val_accuracy did not improve from 0.75974
#
# Epoch 152: val_accuracy did not improve from 0.75974
#
# Epoch 153: val_accuracy did not improve from 0.75974
#
# Epoch 154: val_accuracy did not improve from 0.75974
#
# Epoch 155: val_accuracy did not improve from 0.75974
#
# Epoch 156: val_accuracy did not improve from 0.75974
#
# Epoch 157: val_accuracy did not improve from 0.75974
#
# Epoch 158: val_accuracy did not improve from 0.75974
#
# Epoch 159: val_accuracy did not improve from 0.75974
#
# Epoch 160: val_accuracy did not improve from 0.75974
#
# Epoch 161: val_accuracy did not improve from 0.75974
#
# Epoch 162: val_accuracy did not improve from 0.75974
#
# Epoch 163: val_accuracy did not improve from 0.75974
#
# Epoch 164: val_accuracy did not improve from 0.75974
#
# Epoch 165: val_accuracy did not improve from 0.75974
#
# Epoch 166: val_accuracy did not improve from 0.75974
#
# Epoch 167: val_accuracy did not improve from 0.75974
#
# Epoch 168: val_accuracy did not improve from 0.75974
#
# Epoch 169: val_accuracy did not improve from 0.75974
#
# Epoch 170: val_accuracy did not improve from 0.75974
#
# Epoch 171: val_accuracy did not improve from 0.75974
#
# Epoch 172: val_accuracy did not improve from 0.75974
#
# Epoch 173: val_accuracy did not improve from 0.75974
#
# Epoch 174: val_accuracy did not improve from 0.75974
#
# Epoch 175: val_accuracy did not improve from 0.75974
#
# Epoch 176: val_accuracy did not improve from 0.75974
#
# Epoch 177: val_accuracy did not improve from 0.75974
#
# Epoch 178: val_accuracy did not improve from 0.75974
#
# Epoch 179: val_accuracy did not improve from 0.75974
#
# Epoch 180: val_accuracy did not improve from 0.75974
#
# Epoch 181: val_accuracy did not improve from 0.75974
#
# Epoch 182: val_accuracy did not improve from 0.75974
#
# Epoch 183: val_accuracy did not improve from 0.75974
#
# Epoch 184: val_accuracy did not improve from 0.75974
#
# Epoch 185: val_accuracy did not improve from 0.75974
#
# Epoch 186: val_accuracy did not improve from 0.75974
#
# Epoch 187: val_accuracy did not improve from 0.75974
#
# Epoch 188: val_accuracy did not improve from 0.75974
#
# Epoch 189: val_accuracy did not improve from 0.75974
#
# Epoch 190: val_accuracy did not improve from 0.75974
#
# Epoch 191: val_accuracy did not improve from 0.75974
#
# Epoch 192: val_accuracy did not improve from 0.75974
#
# Epoch 193: val_accuracy did not improve from 0.75974
#
# Epoch 194: val_accuracy did not improve from 0.75974
#
# Epoch 195: val_accuracy did not improve from 0.75974
#
# Epoch 196: val_accuracy did not improve from 0.75974
#
# Epoch 197: val_accuracy did not improve from 0.75974
#
# Epoch 198: val_accuracy did not improve from 0.75974
#
# Epoch 199: val_accuracy did not improve from 0.75974
#
# Epoch 200: val_accuracy did not improve from 0.75974
#
# Epoch 201: val_accuracy did not improve from 0.75974
#
# Epoch 202: val_accuracy did not improve from 0.75974
#
# Epoch 203: val_accuracy did not improve from 0.75974
#
# Epoch 204: val_accuracy did not improve from 0.75974
#
# Epoch 205: val_accuracy did not improve from 0.75974
#
# Epoch 206: val_accuracy did not improve from 0.75974
#
# Epoch 207: val_accuracy did not improve from 0.75974
#
# Epoch 208: val_accuracy did not improve from 0.75974
#
# Epoch 209: val_accuracy did not improve from 0.75974
#
# Epoch 210: val_accuracy did not improve from 0.75974
#
# Epoch 211: val_accuracy did not improve from 0.75974
#
# Epoch 212: val_accuracy did not improve from 0.75974
#
# Epoch 213: val_accuracy did not improve from 0.75974
#
# Epoch 214: val_accuracy did not improve from 0.75974
#
# Epoch 215: val_accuracy did not improve from 0.75974
#
# Epoch 216: val_accuracy did not improve from 0.75974
#
# Epoch 217: val_accuracy did not improve from 0.75974
#
# Epoch 218: val_accuracy did not improve from 0.75974
#
# Epoch 219: val_accuracy did not improve from 0.75974
#
# Epoch 220: val_accuracy did not improve from 0.75974
#
# Epoch 221: val_accuracy did not improve from 0.75974
#
# Epoch 222: val_accuracy did not improve from 0.75974
#
# Epoch 223: val_accuracy did not improve from 0.75974
#
# Epoch 224: val_accuracy did not improve from 0.75974
#
# Epoch 225: val_accuracy did not improve from 0.75974
#
# Epoch 226: val_accuracy did not improve from 0.75974
#
# Epoch 227: val_accuracy did not improve from 0.75974
#
# Epoch 228: val_accuracy did not improve from 0.75974
#
# Epoch 229: val_accuracy did not improve from 0.75974
#
# Epoch 230: val_accuracy did not improve from 0.75974
#
# Epoch 231: val_accuracy did not improve from 0.75974
#
# Epoch 232: val_accuracy did not improve from 0.75974
#
# Epoch 233: val_accuracy did not improve from 0.75974
#
# Epoch 234: val_accuracy did not improve from 0.75974
#
# Epoch 235: val_accuracy did not improve from 0.75974
#
# Epoch 236: val_accuracy did not improve from 0.75974
#
# Epoch 237: val_accuracy did not improve from 0.75974
#
# Epoch 238: val_accuracy did not improve from 0.75974
#
# Epoch 239: val_accuracy did not improve from 0.75974
#
# Epoch 240: val_accuracy did not improve from 0.75974
#
# Epoch 241: val_accuracy did not improve from 0.75974
#
# Epoch 242: val_accuracy did not improve from 0.75974
#
# Epoch 243: val_accuracy did not improve from 0.75974
#
# Epoch 244: val_accuracy did not improve from 0.75974
#
# Epoch 245: val_accuracy did not improve from 0.75974
#
# Epoch 246: val_accuracy did not improve from 0.75974
#
# Epoch 247: val_accuracy did not improve from 0.75974
#
# Epoch 248: val_accuracy did not improve from 0.75974
#
# Epoch 249: val_accuracy did not improve from 0.75974
#
# Epoch 250: val_accuracy did not improve from 0.75974
#
# Epoch 251: val_accuracy did not improve from 0.75974
#
# Epoch 252: val_accuracy did not improve from 0.75974
#
# Epoch 253: val_accuracy did not improve from 0.75974
#
# Epoch 254: val_accuracy did not improve from 0.75974
#
# Epoch 255: val_accuracy did not improve from 0.75974
#
# Epoch 256: val_accuracy did not improve from 0.75974
#
# Epoch 257: val_accuracy did not improve from 0.75974
#
# Epoch 258: val_accuracy did not improve from 0.75974
#
# Epoch 259: val_accuracy improved from 0.75974 to 0.76623, saving model to model_2/checkpoint_best.keras
#
# Epoch 260: val_accuracy did not improve from 0.76623
#
# Epoch 261: val_accuracy did not improve from 0.76623
#
# Epoch 262: val_accuracy did not improve from 0.76623
#
# Epoch 263: val_accuracy did not improve from 0.76623
#
# Epoch 264: val_accuracy did not improve from 0.76623
#
# Epoch 265: val_accuracy did not improve from 0.76623
#
# Epoch 266: val_accuracy did not improve from 0.76623
#
# Epoch 267: val_accuracy did not improve from 0.76623
#
# Epoch 268: val_accuracy did not improve from 0.76623
#
# Epoch 269: val_accuracy did not improve from 0.76623
#
# Epoch 270: val_accuracy did not improve from 0.76623
#
# Epoch 271: val_accuracy did not improve from 0.76623
#
# Epoch 272: val_accuracy did not improve from 0.76623
#
# Epoch 273: val_accuracy did not improve from 0.76623
#
# Epoch 274: val_accuracy did not improve from 0.76623
#
# Epoch 275: val_accuracy did not improve from 0.76623
#
# Epoch 276: val_accuracy did not improve from 0.76623
#
# Epoch 277: val_accuracy did not improve from 0.76623
#
# Epoch 278: val_accuracy did not improve from 0.76623
#
# Epoch 279: val_accuracy did not improve from 0.76623
#
# Epoch 280: val_accuracy did not improve from 0.76623
#
# Epoch 281: val_accuracy did not improve from 0.76623
#
# Epoch 282: val_accuracy did not improve from 0.76623
#
# Epoch 283: val_accuracy did not improve from 0.76623
#
# Epoch 284: val_accuracy did not improve from 0.76623
#
# Epoch 285: val_accuracy did not improve from 0.76623
#
# Epoch 286: val_accuracy did not improve from 0.76623
#
# Epoch 287: val_accuracy did not improve from 0.76623
#
# Epoch 288: val_accuracy did not improve from 0.76623
#
# Epoch 289: val_accuracy did not improve from 0.76623
#
# Epoch 290: val_accuracy did not improve from 0.76623
#
# Epoch 291: val_accuracy did not improve from 0.76623
#
# Epoch 292: val_accuracy did not improve from 0.76623
#
# Epoch 293: val_accuracy did not improve from 0.76623
#
# Epoch 294: val_accuracy did not improve from 0.76623
#
# Epoch 295: val_accuracy did not improve from 0.76623
#
# Epoch 296: val_accuracy did not improve from 0.76623
#
# Epoch 297: val_accuracy did not improve from 0.76623
#
# Epoch 298: val_accuracy did not improve from 0.76623
#
# Epoch 299: val_accuracy did not improve from 0.76623
#
# Epoch 300: val_accuracy did not improve from 0.76623

# %% [markdown]
# ## Заключение
#
# В этом уроке мы узнали как сохранять прогресс обучения и использовать полученные модели.
#
# Следующий этап -- [домашнее задание](https://colab.research.google.com/drive/1G6iHt4PUVrjSHQ80wnCYm3gOtx_Gl1gE), в котором вы примените все полученные знания из этого модуля. Вы снова вернетесь к реализации классификатора известных вам рукописных цифр, но в этот раз сделаете это с помощью Tensorflow.
