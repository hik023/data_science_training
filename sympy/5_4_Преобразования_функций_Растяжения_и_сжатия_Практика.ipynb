# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %% [markdown]
# ## 1.
# ### Получите значение MSE меньшее 50.

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))

    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-15, -1, 4, -9, -2, -5, -8, 4, 13, 21])
    plt.xlim(-3, 6)
    plt.ylim(-20, 20)

    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()

    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f1 = 3.375 * x ** 3 - 9 * x**2
f1
# Out:
#        3      2
# 3.375*x  - 9*x

# %%
print_points_ands_function1(f1)
# Out:
# MSE = 5270.741845703125

# %%
f1_new = f1.subs(x, x*0.7)*0.8
f1_new
# Out:
#         3          2
# 0.9261*x  - 3.528*x

# %%
print_points_ands_function1(f1_new)
# Out:
# MSE = 20.11632025328122

# %% [markdown]
# ## 2.
# ### Получите значение MSE меньшее 150.

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))

    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-10, 10)
    plt.ylim(-70, 70)

    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()

    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')
    # return(MSE)

# %%
f2 = 0.074 * x**3 - 0.11 * x**2 + x + 5
f2
# Out:
#        3         2
# 0.074*x  - 0.11*x  + x + 5

# %%
print_points_ands_function2(f2)
# Out:
# MSE = 1262.7619146666668

# %%
f2_new = f2.subs(x, x*2.4) *1.7
f2_new
# Out:
#            3            2
# 1.7390592*x  - 1.07712*x  + 4.08*x + 8.5

# %%
MSE = 99999999
koef = (1, 1)
for i in range(1, 51):
    for j in range(1, 51):
        MSE_new = print_points_ands_function2(f2.subs(x, x*(i/10)) * (j/10))
        if MSE_new < MSE:
            MSE = MSE_new
            koef = (i/10, j/10)
            print(koef, MSE)
print("FINAL: ", koef, MSE)
# Out:
# (0.1, 0.1) 1489.3140515110933
# (0.1, 0.2) 1487.1280201777056
# (0.1, 0.3) 1485.4419059998384
# (0.1, 0.4) 1484.2557089774903
# (0.1, 0.5) 1483.569429110662
# (0.1, 0.6) 1483.3830663993533
# (0.2, 0.3) 1480.4734718584525
# (0.2, 0.4) 1477.6308875705824
# (0.2, 0.5) 1475.2880991623679
# (0.2, 0.6) 1473.4451066338097
# (0.2, 0.7) 1472.101909984908
# (0.2, 0.8) 1471.2585092156621
# (0.2, 0.9) 1470.9149043260722
# (0.3, 0.4) 1470.5858905083294
# (0.3, 0.5) 1466.4824340859313
# (0.3, 0.6) 1462.8790060437411
# (0.3, 0.7) 1459.7756063817587
# (0.3, 0.8) 1457.1722350999842
# (0.3, 0.9) 1455.0688921984174
# (0.3, 1.0) 1453.465577677059
# (0.3, 1.1) 1452.3622915359076
# (0.3, 1.2) 1451.7590337749646
# (0.3, 1.3) 1451.6558043942293
# (0.4, 0.6) 1451.3829825670352
# (0.4, 0.7) 1446.3680405829084
# (0.4, 0.8) 1441.8544017191732
# (0.4, 0.9) 1437.8420659758285
# (0.4, 1.0) 1434.3310333528746
# (0.4, 1.1) 1431.3213038503118
# (0.4, 1.2) 1428.8128774681397
# (0.4, 1.3) 1426.8057542063582
# (0.4, 1.4) 1425.2999340649676
# (0.4, 1.5) 1424.295417043968
# (0.4, 1.6) 1423.792203143359
# (0.4, 1.7) 1423.7902923631411
# (0.5, 0.9) 1418.80515826375
# (0.5, 1.0) 1413.1956830416668
# (0.5, 1.1) 1408.0908648137502
# (0.5, 1.2) 1403.49070358
# (0.5, 1.3) 1399.3951993404169
# (0.5, 1.4) 1395.8043520950002
# (0.5, 1.5) 1392.71816184375
# (0.5, 1.6) 1390.1366285866668
# (0.5, 1.7) 1388.05975232375
# (0.5, 1.8) 1386.4875330549996
# (0.5, 1.9) 1385.4199707804164
# (0.5, 2.0) 1384.8570654999996
# (0.5, 2.1) 1384.79881721375
# (0.6, 1.1) 1382.1832194212896
# (0.6, 1.2) 1375.269165962527
# (0.6, 1.3) 1368.8666608754654
# (0.6, 1.4) 1362.975704160106
# (0.6, 1.5) 1357.596295816448
# (0.6, 1.6) 1352.7284358444922
# (0.6, 1.7) 1348.3721242442377
# (0.6, 1.8) 1344.527361015685
# (0.6, 1.9) 1341.1941461588342
# (0.6, 2.0) 1338.3724796736853
# (0.6, 2.1) 1336.062361560238
# (0.6, 2.2) 1334.2637918184926
# (0.6, 2.3) 1332.9767704484489
# (0.6, 2.4) 1332.201297450107
# (0.6, 2.5) 1331.9373728234666
# (0.7, 1.4) 1326.2743453325222
# (0.7, 1.5) 1318.3664311827422
# (0.7, 1.6) 1310.9824680479198
# (0.7, 1.7) 1304.1224559280552
# (0.7, 1.8) 1297.7863948231486
# (0.7, 1.9) 1291.9742847331995
# (0.7, 2.0) 1286.686125658208
# (0.7, 2.1) 1281.9219175981746
# (0.7, 2.2) 1277.6816605530983
# (0.7, 2.3) 1273.96535452298
# (0.7, 2.4) 1270.7729995078196
# (0.7, 2.5) 1268.1045955076168
# (0.7, 2.6) 1265.9601425223718
# (0.7, 2.7) 1264.3396405520841
# (0.7, 2.8) 1263.2430895967545
# (0.7, 2.9) 1262.6704896563822
# (0.7, 3.0) 1262.621840730968
# (0.8, 1.7) 1254.7968558298319
# (0.8, 1.8) 1245.7439494728908
# (0.8, 1.9) 1237.2355119793626
# (0.8, 2.0) 1229.2715433492478
# (0.8, 2.1) 1221.852043582546
# (0.8, 2.2) 1214.9770126792566
# (0.8, 2.3) 1208.6464506393804
# (0.8, 2.4) 1202.8603574629171
# (0.8, 2.5) 1197.6187331498668
# (0.8, 2.6) 1192.9215777002291
# (0.8, 2.7) 1188.7688911140046
# (0.8, 2.8) 1185.1606733911929
# (0.8, 2.9) 1182.096924531794
# (0.8, 3.0) 1179.5776445358078
# (0.8, 3.1) 1177.602833403235
# (0.8, 3.2) 1176.1724911340746
# (0.8, 3.3) 1175.2866177283274
# (0.8, 3.4) 1174.9452131859935
# (0.9, 2.0) 1165.7554393164053
# (0.9, 2.1) 1155.4961640263368
# (0.9, 2.2) 1145.8133604261836
# (0.9, 2.3) 1136.7070285159464
# (0.9, 2.4) 1128.177168295624
# (0.9, 2.5) 1120.2237797652167
# (0.9, 2.6) 1112.8468629247247
# (0.9, 2.7) 1106.0464177741487
# (0.9, 2.8) 1099.8224443134877
# (0.9, 2.9) 1094.1749425427422
# (0.9, 3.0) 1089.1039124619122
# (0.9, 3.1) 1084.609354070997
# (0.9, 3.2) 1080.6912673699974
# (0.9, 3.3) 1077.3496523589135
# (0.9, 3.4) 1074.5845090377447
# (0.9, 3.5) 1072.3958374064914
# (0.9, 3.6) 1070.783637465153
# (0.9, 3.7) 1069.7479092137303
# (0.9, 3.8) 1069.2886526522234
# (1.0, 2.3) 1058.0780219200003
# (1.0, 2.4) 1046.7028684799998
# (1.0, 2.5) 1035.9519666666667
# (1.0, 2.6) 1025.8253164799999
# (1.0, 2.7) 1016.3229179199999
# (1.0, 2.8) 1007.4447709866668
# (1.0, 2.9) 999.19087568
# (1.0, 3.0) 991.5612319999997
# (1.0, 3.1) 984.5558399466667
# (1.0, 3.2) 978.1746995199998
# (1.0, 3.3) 972.41781072
# (1.0, 3.4) 967.2851735466666
# (1.0, 3.5) 962.7767880000001
# (1.0, 3.6) 958.8926540800002
# (1.0, 3.7) 955.6327717866667
# (1.0, 3.8) 952.99714112
# (1.0, 3.9) 950.9857620799999
# (1.0, 4.0) 949.5986346666667
# (1.0, 4.1) 948.8357588800001
# (1.0, 4.2) 948.6971347200001
# (1.1, 2.5) 945.1791987512166
# (1.1, 2.6) 932.3179739986491
# (1.1, 2.7) 920.1499498074189
# (1.1, 2.8) 908.6751261775262
# (1.1, 2.9) 897.8935031089708
# (1.1, 3.0) 887.8050806017519
# (1.1, 3.1) 878.4098586558706
# (1.1, 3.2) 869.7078372713266
# (1.1, 3.3) 861.6990164481198
# (1.1, 3.4) 854.3833961862503
# (1.1, 3.5) 847.760976485718
# (1.1, 3.6) 841.8317573465229
# (1.1, 3.7) 836.595738768665
# (1.1, 3.8) 832.0529207521441
# (1.1, 3.9) 828.2033032969608
# (1.1, 4.0) 825.0468864031144
# (1.1, 4.1) 822.5836700706058
# (1.1, 4.2) 820.8136542994338
# (1.1, 4.3) 819.7368390895994
# (1.1, 4.4) 819.3532244411017
# (1.2, 2.7) 818.5522006074572
# (1.2, 2.8) 804.6698071652216
# (1.2, 2.9) 791.5774221262985
# (1.2, 3.0) 779.2750454906882
# (1.2, 3.1) 767.7626772583902
# (1.2, 3.2) 757.040317429405
# (1.2, 3.3) 747.1079660037325
# (1.2, 3.4) 737.9656229813727
# (1.2, 3.5) 729.6132883623254
# (1.2, 3.6) 722.0509621465908
# (1.2, 3.7) 715.2786443341688
# (1.2, 3.8) 709.2963349250598
# (1.2, 3.9) 704.1040339192627
# (1.2, 4.0) 699.7017413167787
# (1.2, 4.1) 696.0894571176074
# (1.2, 4.2) 693.2671813217486
# (1.2, 4.3) 691.2349139292024
# (1.2, 4.4) 689.9926549399689
# (1.2, 4.5) 689.5404043540483
# (1.3, 2.9) 682.175195006651
# (1.3, 3.0) 668.0934350320878
# (1.3, 3.1) 654.9345572775961
# (1.3, 3.2) 642.6985617431757
# (1.3, 3.3) 631.3854484288266
# (1.3, 3.4) 620.9952173345486
# (1.3, 3.5) 611.5278684603419
# (1.3, 3.6) 602.9834018062065
# (1.3, 3.7) 595.3618173721427
# (1.3, 3.8) 588.6631151581502
# (1.3, 3.9) 582.8872951642287
# (1.3, 4.0) 578.0343573903787
# (1.3, 4.1) 574.1043018366
# (1.3, 4.2) 571.0971285028925
# (1.3, 4.3) 569.0128373892564
# (1.3, 4.4) 567.8514284956914
# (1.3, 4.5) 567.6129018221981
# (1.4, 3.0) 557.1732816619522
# (1.4, 3.1) 543.0900778279288
# (1.4, 3.2) 530.1086602375989
# (1.4, 3.3) 518.229028890962
# (1.4, 3.4) 507.4511837880184
# (1.4, 3.5) 497.7751249287682
# (1.4, 3.6) 489.200852313211
# (1.4, 3.7) 481.7283659413472
# (1.4, 3.8) 475.3576658131765
# (1.4, 3.9) 470.08875192869897
# (1.4, 4.0) 465.9216242879147
# (1.4, 4.1) 462.8562828908239
# (1.4, 4.2) 460.89272773742596
# (1.4, 4.3) 460.0309588277216
# (1.5, 3.0) 450.33573637500007
# (1.5, 3.1) 436.36348684041656
# (1.5, 3.2) 423.7299400533332
# (1.5, 3.3) 412.43509601375007
# (1.5, 3.4) 402.47895472166675
# (1.5, 3.5) 393.8615161770833
# (1.5, 3.6) 386.58278038000003
# (1.5, 3.7) 380.64274733041657
# (1.5, 3.8) 376.04141702833334
# (1.5, 3.9) 372.7787894737501
# (1.5, 4.0) 370.85486466666674
# (1.5, 4.1) 370.26964260708354
# (1.6, 2.9) 366.52754295001085
# (1.6, 3.0) 352.4368547717118
# (1.6, 3.1) 339.994080386239
# (1.6, 3.2) 329.1992197935922
# (1.6, 3.3) 320.05227299377145
# (1.6, 3.4) 312.55323998677665
# (1.6, 3.5) 306.702120772608
# (1.6, 3.6) 302.4989153512652
# (1.6, 3.7) 299.94362372274855
# (1.6, 3.8) 299.0362458870578
# (1.7, 2.8) 293.70701533432884
# (1.7, 2.9) 280.582243076408
# (1.7, 3.0) 269.503774664408
# (1.7, 3.1) 260.471610098329
# (1.7, 3.2) 253.48574937817088
# (1.7, 3.3) 248.54619250393378
# (1.7, 3.4) 245.65293947561744
# (1.7, 3.5) 244.80599029322198
# (1.8, 2.7) 233.768084486318
# (1.8, 2.8) 222.91846814001838
# (1.8, 2.9) 214.6225350587017
# (1.8, 3.0) 208.88028524236802
# (1.8, 3.1) 205.69171869101737
# (1.8, 3.2) 205.05683540464983
# (1.9, 2.5) 198.58069874721664
# (1.9, 2.6) 188.35465124232283
# (1.9, 2.7) 181.32173639475351
# (1.9, 2.8) 177.4819542045086
# (1.9, 2.9) 176.83530467158812
# (2.0, 2.3) 173.61393088000003
# (2.0, 2.4) 164.18921472000002
# (2.0, 2.5) 158.75586666666666
# (2.0, 2.6) 157.31388672
# (2.1, 2.1) 157.23493076027924
# (2.1, 2.2) 148.44508934416137
# (2.1, 2.3) 144.63437519861165
# (2.2, 2.0) 139.09675226316799
# (2.2, 2.1) 136.46314153014268
# (2.3, 1.8) 134.52762014559332
# (2.3, 1.9) 131.9654981424666
# (2.4, 1.7) 129.6795684614281
# FINAL:  (2.4, 1.7) 129.6795684614281

# %%
print_points_ands_function2(f2_new)
# Out:
# MSE = 129.6795684614281
